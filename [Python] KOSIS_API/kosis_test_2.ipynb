# %%
기관코드 = '101'
통계표ID = 'DT_1DA7012S'

# %%
# 성별 코드
sex_id = {
    '계': '0',
    '남자': '2',
    '여자': '3'
}

# 연령 코드
age_id = {
    '계': '00',
    '15 - 29세': '75',
    '15 - 19세': '10',
    '20 - 29세': '20',
    '20 - 24세': '201',
    '25 - 29세': '202',
    '30 - 39세': '30',
    '30 - 34세': '301',
    '35 - 39세': '302',
    '40 - 49세': '40',
    '40 - 44세': '401',
    '45 - 49세': '402',
    '50 - 59세': '50',
    '50 - 54세': '501',
    '55 - 59세': '502',
    '60세이상': '60',
    '60 - 64세': '601',    
    '65세 이상': '602',    
    '15 - 64세': '63',
    '15 - 24세': '70'
}

# 항목 코드
itm_id = {
    '인구': 'T10',
    '경제활동인구': 'T20',
    '취업자': 'T30',
    '실업자': 'T40',
    '비경제활동인구': 'T50',
    '경제활동참가율': 'T60',
    '실업률': 'T80',
    '고용률': 'T90'
}

# %%
query = 'https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=MDUwYjkzYmRhZjc4Yzk5M2QyZDg1NDBhNjNlOTNjZmQ=&itmId=T10+&objL1=0+&objL2=00+&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=M&startPrdDe=199906&endPrdDe=202012&loadGubun=1&orgId=101&tblId=DT_1DA7012S'
query = 'https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=MDUwYjkzYmRhZjc4Yzk5M2QyZDg1NDBhNjNlOTNjZmQ=&itmId={0}+&objL1={1}+&objL2={2}+&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=M&startPrdDe=199906&endPrdDe=202012&loadGubun=1&orgId=101&tblId=DT_1DA7012S'

# %%
import requests
import pandas as pd
import time, random

# %%
df = pd.DataFrame()

for item in itm_id.values():
  for sex in sex_id.values():
    for age in age_id.values():
      query_temp = query.format(item, sex, age)
      r = requests.get(query_temp)
      data = r.json()
      df_temp = pd.DataFrame(data)
      df = df.append(df_temp, ignore_index=True)
      print(item, sex, age, df.shape)

      time.sleep(random.uniform(1,3))
# Out:
# T10 0 00 (259, 21)
# T10 0 75 (518, 21)
# T10 0 10 (777, 21)
# T10 0 20 (1036, 21)
# T10 0 201 (1295, 21)
# T10 0 202 (1554, 21)
# T10 0 30 (1813, 21)
# T10 0 301 (2072, 21)
# T10 0 302 (2331, 21)
# T10 0 40 (2590, 21)
# T10 0 401 (2849, 21)
# T10 0 402 (3108, 21)
# T10 0 50 (3367, 21)
# T10 0 501 (3626, 21)
# T10 0 502 (3885, 21)
# T10 0 60 (4144, 21)
# T10 0 601 (4403, 21)
# T10 0 602 (4662, 21)
# T10 0 63 (4921, 21)
# T10 0 70 (5180, 21)
# T10 2 00 (5439, 21)
# T10 2 75 (5698, 21)
# T10 2 10 (5957, 21)
# T10 2 20 (6216, 21)
# T10 2 201 (6475, 21)
# T10 2 202 (6734, 21)
# T10 2 30 (6993, 21)
# T10 2 301 (7252, 21)
# T10 2 302 (7511, 21)
# T10 2 40 (7770, 21)
# T10 2 401 (8029, 21)
# T10 2 402 (8288, 21)
# T10 2 50 (8547, 21)
# T10 2 501 (8806, 21)
# T10 2 502 (9065, 21)
# T10 2 60 (9324, 21)
# T10 2 601 (9583, 21)
# T10 2 602 (9842, 21)
# T10 2 63 (10101, 21)
# T10 2 70 (10360, 21)
# T10 3 00 (10619, 21)
# T10 3 75 (10878, 21)
# T10 3 10 (11137, 21)
# T10 3 20 (11396, 21)
# ...

# %%
df.head()
# Out:
#          TBL_NM  PRD_DE       TBL_ID   ITM_NM  ... C1_NM C2_NM C1_NM_ENG C2_NM_ENG
# 0  성/연령별 경제활동인구  199906  DT_1DA7012S  15세이상인구  ...     계     계     Total     Total
# 1  성/연령별 경제활동인구  199907  DT_1DA7012S  15세이상인구  ...     계     계     Total     Total
# 2  성/연령별 경제활동인구  199908  DT_1DA7012S  15세이상인구  ...     계     계     Total     Total
# 3  성/연령별 경제활동인구  199909  DT_1DA7012S  15세이상인구  ...     계     계     Total     Total
# 4  성/연령별 경제활동인구  199910  DT_1DA7012S  15세이상인구  ...     계     계     Total     Total
#
# [5 rows x 21 columns]

# %%
df_final = df[['PRD_DE', 'ITM_NM', 'ITM_ID', 'C1_NM', 'C1', 'C2_NM', 'C2', 'DT']]

# %%
from google.colab import files
df_final.to_csv('Kosis_Data(utf-8-sig).csv', encoding='utf-8-sig')
files.download('Kosis_Data(utf-8-sig).csv')
